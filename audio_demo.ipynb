# %%
import torch
import torchaudio
import matplotlib.pyplot as plt

# %%
waveform, sample_rate = torchaudio.load("../data/lengua.wav")
print("Shape of waveform: {}".format(waveform.size()))
print("Sample rate of waveform: {}".format(sample_rate))
# Out:
# Shape of waveform: torch.Size([2, 6132105])
# Sample rate of waveform: 44100

# %%
plt.figure()
plt.plot(waveform.t().numpy())
# Out:
# [<matplotlib.lines.Line2D at 0x7f48f54c1c18>,
#  <matplotlib.lines.Line2D at 0x7f48f54c1e10>]

# %%
specgram = torchaudio.transforms.Spectrogram()(waveform)

print("Shape of spectrogram: {}".format(specgram.size()))
# Out:
# Shape of spectrogram: torch.Size([2, 201, 30661])

# %%
plt.figure(figsize=(10,10))
plt.imshow(specgram.log2()[0,:,0:5000].numpy(), cmap='gray')
